# %% [markdown]
# # Data Analysis with Python

# %% [markdown]
# Mohammad Monirul Hasan Tipu\
# Researcher, BARI, Gazipur, Bangladesh

# %% [markdown]
# #### Objectives:
# Reading the excel file\
# In the current case, displaying the first 10 rows of the dataframe\
# Describing each column of the dataset\
# Displaying number of rows\
# Displaying number of columns\
# Finding data statistics\
# Checking the data types\
# Checking for missing any value\
# Renaming the column names\
# Removing a column from the dataframe\
# Removing the columns BBI and BBM from the dataframe\
# Identifying how many players played for ICC\
# Number of different countries present in this dataset\
# Finding player(s) who had played for the longest period of time\
# Finding player(s) who had played for the shortest period of time\
# Number of Australian bowlers who are present in this dataset\
# Finding if any Bangladeshi player present in this dataset\
# The player who had the lowest economy rate\
# The player who had the lowest strike rate\
# The player who had the lowest bowling average

# %% [markdown]
# Data Source: https://stats.espncricinfo.com/ci/content/records/223646.html

# %% [markdown]
# ### HW 1 from Lecture 01 & Lecture 02

# %% [markdown]
# #### Importing required libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### Changing the directory

# %%
os.chdir(r'G:\Tipu_BARI_2013\Online courses\EMK_Data Analysis with Python\Data_Analysis_with_Python-main\HW1')
os.getcwd()
# Out:
# 'G:\\Tipu_BARI_2013\\Online courses\\EMK_Data Analysis with Python\\Data_Analysis_with_Python-main\\HW1'

# %% [markdown]
# #### Reading an excel file

# %%
# reading an excel file
df = pd.read_excel("test_cricket.xlsx", sheet_name = 'wickets')
display(df)
# Out:
#                      Player       Span  Mat  Inns  Balls   Runs  Wkts  \
# 0   M Muralitharan (ICC/SL)  1992-2010  133   230  44039  18180   800
# 1            SK Warne (AUS)  1992-2007  145   273  40705  17995   708
# 2          A Kumble (INDIA)  1990-2008  132   236  40850  18355   619
# 3         JM Anderson (ENG)  2003-2021  162   301  34791  16457   617
# 4          GD McGrath (AUS)  1993-2007  124   243  29248  12186   563
# ..                      ...        ...  ...   ...    ...    ...   ...
# 74        SCG MacGill (AUS)  1998-2008   44    85  11237   6038   208
# 75    Saqlain Mushtaq (PAK)  1995-2004   49    86  14070   6206   208
# 76         AME Roberts (WI)  1974-1983   47    90  11135   5174   202
# 77            JA Snow (ENG)  1965-1976   49    93  12021   5387   202
# 78         JR Thomson (AUS)  1972-1985   51    90  10535   5601   200
#
#                     BBI                  BBM    Ave  Econ    SR   5  10
# ...

# %% [markdown]
# #### Displaying the first 10 rows of the dataframe

# %%
display(df.head(10))
# Out:
#                     Player       Span  Mat  Inns  Balls   Runs  Wkts  \
# 0  M Muralitharan (ICC/SL)  1992-2010  133   230  44039  18180   800
# 1           SK Warne (AUS)  1992-2007  145   273  40705  17995   708
# 2         A Kumble (INDIA)  1990-2008  132   236  40850  18355   619
# 3        JM Anderson (ENG)  2003-2021  162   301  34791  16457   617
# 4         GD McGrath (AUS)  1993-2007  124   243  29248  12186   563
# 5          SCJ Broad (ENG)  2007-2021  148   272  29713  14502   523
# 6            CA Walsh (WI)  1984-2001  132   242  30019  12688   519
# 7            DW Steyn (SA)  2004-2019   93   171  18608  10077   439
# 8      N Kapil Dev (INDIA)  1978-1994  131   227  27740  12867   434
# 9        HMRKB Herath (SL)  1999-2018   93   170  25993  12157   433
#
#                    BBI                  BBM    Ave  Econ    SR   5  10
# 0  1951-09-01 00:00:00               16/220  22.72  2.47  55.0  67  22
# ...

# %% [markdown]
# ##### ***Here each column has been described as 'Player'= 'Player_Name', 'Span'= 'Career_duration', 'Mat'= 'Number_of_match_played', 'Inns' = 'Number_of_innings', 'Balls'='Number_of_balls_bowled', 'Runs'= 'Runs_considered', 'Wkts' = 'Total_wickets_taken', 'BBI' = 'Best_Bowling_in_Innings', 'BBM' = 'Best_Bowling_in_Match', 'Ave' = 'Average_runs_per_wicket', 'Econ' = 'Average_runs_conceded_per_over', 'SR'= 'Strike_rate', 5 = 'Number_of_times_5_wickets_taken', 10 = 'Number_of_times_10_wickets_taken'

# %% [markdown]
# #### Number of rows

# %%
print("number of rows = ", df.shape[0])
# Out:
# number of rows =  79

# %% [markdown]
# #### Number of columns

# %%
print("number of columns = ", df.shape[1])
# Out:
# number of columns =  14

# %% [markdown]
# #### Finding data statistics

# %%
display(df.describe())
# Out:
#               Mat        Inns         Balls          Runs        Wkts  \
# count   79.000000   79.000000     79.000000     79.000000   79.000000
# mean    80.101266  144.797468  18630.303797   8595.506329  317.101266
# std     28.537692   51.042310   7190.036515   3080.256645  121.731587
# min     37.000000   67.000000   8785.000000   4846.000000  200.000000
# 25%     60.500000  110.000000  13580.000000   6456.500000  229.000000
# 50%     71.000000  129.000000  16498.000000   7742.000000  266.000000
# 75%     93.000000  169.000000  21742.500000   9756.000000  374.500000
# max    166.000000  301.000000  44039.000000  18355.000000  800.000000
#
#              Ave       Econ         SR          5         10
# count  79.000000  79.000000  79.000000  79.000000  79.000000
# mean   27.466456   2.806582  59.187342  16.354430   2.797468
# std     3.657561   0.351666   9.349337   9.642372   3.235935
# min    20.940000   1.980000  41.200000   3.000000   0.000000
# ...

# %% [markdown]
# #### Checking the data types

# %%
print(df.dtypes)
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# Balls       int64
# Runs        int64
# Wkts        int64
# BBI        object
# BBM        object
# Ave       float64
# Econ      float64
# SR        float64
# 5           int64
# 10          int64
# dtype: object

# %% [markdown]
# ##### Checking for missing value here

# %%
print(df.isnull())
# Out:
#     Player   Span    Mat   Inns  Balls   Runs   Wkts    BBI    BBM    Ave  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 74   False  False  False  False  False  False  False  False  False  False
# 75   False  False  False  False  False  False  False  False  False  False
# 76   False  False  False  False  False  False  False  False  False  False
# 77   False  False  False  False  False  False  False  False  False  False
# 78   False  False  False  False  False  False  False  False  False  False
#
#      Econ     SR      5     10
# 0   False  False  False  False
# ...

# %% [markdown]
# ##### There is no missing value in this dataset

# %% [markdown]
# #### Renaming the column names

# %%
df = df.rename(columns = {'Player':'Player_name', 
                        'Span':'Playing_span',
                        'Mat': 'Matche_played',
                        'Inns' : 'Innings_bowled',
                        'Runs' : 'Runs_conced',
                        'Ave' : 'Bowling_average',
                        'Econ' : 'Economy_rate',
                        'SR' : 'Bowling_strike_rate',
                        'Ave': 'Average',
                         5 : 'Five_wickets',
                         10 : 'Ten_wickets'})
display(df.head())
# Out:
#                Player_name Playing_span  Matche_played  Innings_bowled  Balls  \
# 0  M Muralitharan (ICC/SL)    1992-2010            133             230  44039
# 1           SK Warne (AUS)    1992-2007            145             273  40705
# 2         A Kumble (INDIA)    1990-2008            132             236  40850
# 3        JM Anderson (ENG)    2003-2021            162             301  34791
# 4         GD McGrath (AUS)    1993-2007            124             243  29248
#
#    Runs_conced  Wkts                  BBI                  BBM  Average  \
# 0        18180   800  1951-09-01 00:00:00               16/220    22.72
# 1        17995   708  1971-08-01 00:00:00               12/128    25.41
# 2        18355   619  1974-10-01 00:00:00               14/149    29.65
# 3        16457   617  1942-07-01 00:00:00  1971-11-01 00:00:00    26.67
# 4        12186   563  2021-08-24 00:00:00  2021-10-27 00:00:00    21.64
#
#    Economy_rate  Bowling_strike_rate  Five_wickets  Ten_wickets
# ...

# %% [markdown]
# #### Removing a column from the dataframe

# %%
df.drop('Ten_wickets', axis=1, inplace=True)
display(df.head())
# Out:
#                Player_name Playing_span  Matche_played  Innings_bowled  Balls  \
# 0  M Muralitharan (ICC/SL)    1992-2010            133             230  44039
# 1           SK Warne (AUS)    1992-2007            145             273  40705
# 2         A Kumble (INDIA)    1990-2008            132             236  40850
# 3        JM Anderson (ENG)    2003-2021            162             301  34791
# 4         GD McGrath (AUS)    1993-2007            124             243  29248
#
#    Runs_conced  Wkts                  BBI                  BBM  Average  \
# 0        18180   800  1951-09-01 00:00:00               16/220    22.72
# 1        17995   708  1971-08-01 00:00:00               12/128    25.41
# 2        18355   619  1974-10-01 00:00:00               14/149    29.65
# 3        16457   617  1942-07-01 00:00:00  1971-11-01 00:00:00    26.67
# 4        12186   563  2021-08-24 00:00:00  2021-10-27 00:00:00    21.64
#
#    Economy_rate  Bowling_strike_rate  Five_wickets
# ...

# %% [markdown]
# ## This is the END of assignment HW1

# %% [markdown]
# ### HW 1 from Lecture 04 & Lecture 05

# %% [markdown]
# #### Removing the columns BBI and BBM from the dataframe

# %%
df.drop(['BBI','BBM'], axis=1, inplace=True)
df.head()
# Out:
#                Player_name Playing_span  Matche_played  Innings_bowled  Balls  \
# 0  M Muralitharan (ICC/SL)    1992-2010            133             230  44039
# 1           SK Warne (AUS)    1992-2007            145             273  40705
# 2         A Kumble (INDIA)    1990-2008            132             236  40850
# 3        JM Anderson (ENG)    2003-2021            162             301  34791
# 4         GD McGrath (AUS)    1993-2007            124             243  29248
#
#    Runs_conced  Wkts  Average  Economy_rate  Bowling_strike_rate  Five_wickets
# 0        18180   800    22.72          2.47                 55.0            67
# 1        17995   708    25.41          2.65                 57.4            37
# 2        18355   619    29.65          2.69                 65.9            35
# 3        16457   617    26.67          2.83                 56.3            30
# 4        12186   563    21.64          2.49                 51.9            29

# %% [markdown]
# #### Identifying how many players played for ICC

# %%
# splitting the 'Player' column to get the information about 'Country'
df_player = df['Player_name'].str.split("(", expand=True)

# concatinating 'Country' with the main dataframe
df = pd.concat([df, df_player], axis=1)

# dropping the 'Player' columns
df = df.drop('Player_name', axis=1)

# renaming the column names
df = df.rename(columns={0: 'Player',
                        1: 'Country'})

# remove the ")" from the 'Country' column
df['Country'] = df['Country'].str.replace(")", "", regex=True)

# rearrange the columns
new_col_sequence = ['Player', 'Country' , 'Playing_span', 'Matche_played', 'Innings_bowled', 'Balls', 'Runs_conced', 'Wkts',
                    'Average', 'Economy_rate', 'Bowling_strike_rate', 'Five_wickets']
df = df[new_col_sequence]
df.head()
# Out:
#             Player Country Playing_span  Matche_played  Innings_bowled  Balls  \
# 0  M Muralitharan   ICC/SL    1992-2010            133             230  44039
# 1        SK Warne      AUS    1992-2007            145             273  40705
# 2        A Kumble    INDIA    1990-2008            132             236  40850
# 3     JM Anderson      ENG    2003-2021            162             301  34791
# 4      GD McGrath      AUS    1993-2007            124             243  29248
#
#    Runs_conced  Wkts  Average  Economy_rate  Bowling_strike_rate  Five_wickets
# 0        18180   800    22.72          2.47                 55.0            67
# 1        17995   708    25.41          2.65                 57.4            37
# 2        18355   619    29.65          2.69                 65.9            35
# 3        16457   617    26.67          2.83                 56.3            30
# 4        12186   563    21.64          2.49                 51.9            29

# %%
# A function can be useful to identify how many players played for ICC
def icc_check(x):
    if "ICC" in x:
        return "Yes"
    else:
        return "No"


df['Played_for_ICC'] = df['Country'].apply(icc_check)
# df['played_for_INDIA'] = df['Country'].apply(INDIA_check)

df['Played_for_ICC'].value_counts()
# Out:
# No     74
# Yes     5
# Name: Played_for_ICC, dtype: int64

# %% [markdown]
# #### Number of different countries present in this dataset

# %%
df['Country'] = df['Country'].str.replace("ICC/", "")
df['Country'] = df['Country'].str.replace("/ICC", "")

print("There are number of different counteries present in Country column is: ",(len(df['Country'].unique())))
# Out:
# There are number of different counteries present in Country column is:  10

# %% [markdown]
# #### Finding player(s) who had played for the longest period of time

# %%
df_span = df['Playing_span'].str.split("-", expand=True)

# conccatinating the new dataframe with the main dataframe
df = pd.concat([df, df_span], axis=1)

# renaming the newly created column names
df = df.rename(columns={0: "Start_year",
                        1: "End_year"})

# removing the "Span" column
df = df.drop("Playing_span", axis=1)


### Changing datatype
df['Start_year'] = df['Start_year'].astype('int') 
df['End_year'] = df['End_year'].astype('int')

# %%
df['Years_played'] = df['End_year'] - df['Start_year']
df = df.drop(['Start_year', "End_year"], axis=1)

#df.loc[df['Years_played'] == (df['Years_played'].max()), 'Player']
print("Player played for the longest period of time is: ", df.loc[df['Years_played'] == (df['Years_played'].max()), 'Player'].iloc[0])
# Out:
# Player played for the longest period of time is:  Imran Khan

# %% [markdown]
# #### Finding player(s) who had played for the shortest period of time

# %%
print("Player played for the shortest period of time is: ", df.loc[df['Years_played'] == (df['Years_played'].min()), 'Player'].iloc[0])
# Out:
# Player played for the shortest period of time is:  GP Swann

# %% [markdown]
# #### Number of Australian bowlers who are present in this dataset

# %%
df['Country'].value_counts()
# Out:
# AUS      18
# ENG      15
# INDIA    10
# WI        9
# SA        8
# NZ        7
# PAK       7
# SL        3
# BDESH     1
# ZIM       1
# Name: Country, dtype: int64

# %% [markdown]
# ###### There are 18 Australian bowlers here in this dataset

# %% [markdown]
# #### Finding if any Bangladeshi player present in this dataset

# %%
df['Country'].value_counts()
# Out:
# AUS      18
# ENG      15
# INDIA    10
# WI        9
# SA        8
# NZ        7
# PAK       7
# SL        3
# BDESH     1
# ZIM       1
# Name: Country, dtype: int64

# %% [markdown]
# ##### There is 1 Bangladeshi player present in this dataset

# %% [markdown]
# #### The player who had the lowest economy rate

# %%
print("\nLowest Economy rate\n" ,df.sort_values(by="Economy_rate", ascending = True).iloc[0,[0]])
# Out:
# Lowest Economy rate
#  Player    LR Gibbs
# Name: 32, dtype: object

# %% [markdown]
# #### The player who had the lowest strike rate

# %%
print("\nLowest Bowling strike\n" ,df.sort_values(by="Bowling_strike_rate", ascending = True).iloc[0,[0]])
# Out:
# Lowest Bowling strike
#  Player    K Rabada
# Name: 71, dtype: object

# %% [markdown]
# #### The player who had the lowest bowling average

# %%
print("Lowest Average\n" ,df.sort_values(by="Average", ascending = True).iloc[0,[0]])
# Out:
# Lowest Average
#  Player    MD Marshall
# Name: 19, dtype: object

# %% [markdown]
# ## This is the END of assignment HW2
